# %% [markdown]
# # Brain Tumor Classification: ResNet18 Training
#
# This notebook trains the **ResNet18** model with Anti-Clever-Hans regularization.
#
# ## Architectural Cause and Role in Ensemble
# - **Mathematical Cause**: Deep residual learning with identity skip connections (y = F(x) + x).
# - **Key Strength**: Solves vanishing gradients, producing a smooth optimization landscape and wide receptive field.
# - **Diagnostic Role**: Acts as the **Structural Anchor** in the multi-model ensemble, detecting global brain symmetry and large-scale anatomical displacements (e.g. midline shifts).
# - **Parameters**: ~11.2M parameters.
#
# ## Anti-Clever-Hans Pipeline
# - **CenterBiasedCrop**: Directs attention toward intracranial structures rather than peripheral skull artifacts.
# - **Mixup Augmentation & RandomErasing**: Discourages reliance on localized shortcut markers.
# - **Grayscale Normalization**: Eliminates artificial color biases across different MRI scanner protocols.

# %%
# Ensure both notebooks/ and src/ are in sys.path regardless of execution working directory
import sys
from pathlib import Path
_cwd = Path.cwd().resolve()
_nb_dir = _cwd if (_cwd / 'custom_transforms.py').exists() else _cwd / 'notebooks'
_proj_root = _nb_dir.parent if _nb_dir.name == 'notebooks' else _nb_dir
_src_dir = _proj_root / 'src'
for _p in (_nb_dir, _src_dir, _proj_root):
    if _p.exists() and str(_p) not in sys.path:
        sys.path.insert(0, str(_p))

# Allow importing shared package
import sys
from pathlib import Path
SRC_PATH = Path.cwd().resolve().parent / 'src'
if SRC_PATH.exists() and str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from brain_tumor.model_factory import create_model
from brain_tumor.device import get_device
import os
import json
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, ConcatDataset, Subset
from torchvision import datasets, models
from copy import deepcopy
import matplotlib.pyplot as plt

# Import Anti-Clever-Hans transforms and helpers
from custom_transforms import (
    build_train_transforms,
    build_val_transforms,
    CenterBiasedCrop,
)
from perf_helpers import (
    autocast_context,
    configure_cuda_perf,
    get_adamw_kwargs,
    get_dataloader_kwargs,
    get_grad_scaler,
    is_cuda_device,
    maybe_channels_last,
    maybe_compile,
    move_batch,
    mixup_data,
    mixup_criterion,
    train_step_with_mixup,
    LabelSmoothingCrossEntropy,
)

# Device selection
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using device: MPS (Apple Silicon GPU)")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using device: CUDA")
else:
    device = torch.device("cpu")
    print("Using device: CPU")

print(f"PyTorch version: {torch.__version__}")


def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


set_seed(42)
print("Seeds set to 42.")
configure_cuda_perf(device)
use_cuda = is_cuda_device(device)
scaler = get_grad_scaler(device)

# Anti-Clever-Hans config
MIXUP_ALPHA = 0.2  # Mixup strength (0 = disabled)
GRADIENT_CLIP = 1.0  # Gradient clipping norm
# Out:
# Using device: CUDA
# PyTorch version: 2.5.1
# Seeds set to 42.

# %%
from pathlib import Path

BASE_DIR = Path.cwd().resolve()
while not (BASE_DIR / "data").exists() and BASE_DIR.parent != BASE_DIR:
    BASE_DIR = BASE_DIR.parent

data_dir = BASE_DIR / "data" / "Brain_Tumor_Dataset" / "Training"
external_data_dir = (
    BASE_DIR / "data" / "Brain_Tumor_Dataset" / "external_dataset" / "training"
)

# %%
# Anti-Clever-Hans Data Transforms
# Key: Center-biased cropping forces model to focus on brain tissue, not edges/skull

IMG_SIZE = 224

# Use the new anti-Clever-Hans transforms
train_tf = build_train_transforms(image_size=IMG_SIZE, anti_clever_hans=True)
val_tf = build_val_transforms(image_size=IMG_SIZE)

print("Anti-Clever-Hans transforms enabled:")
print("  - CenterBiasedCrop: 70% center focus")
print("  - RandomErasing: Prevents region over-reliance")
print("  - Grayscale: Removes color artifacts")
print("  - Strict CenterCrop for validation")
# Out:
# Anti-Clever-Hans transforms enabled:
#   - CenterBiasedCrop: 70% center focus
#   - RandomErasing: Prevents region over-reliance
#   - Grayscale: Removes color artifacts
#   - Strict CenterCrop for validation

# %%
# Load Datasets with Anti-Clever-Hans transforms
print("Loading datasets...")
dataset1_train = datasets.ImageFolder(root=data_dir, transform=train_tf)
dataset1_val = datasets.ImageFolder(root=data_dir, transform=val_tf)

try:
    dataset2_train = datasets.ImageFolder(root=external_data_dir, transform=train_tf)
    dataset2_val = datasets.ImageFolder(root=external_data_dir, transform=val_tf)

    full_train = ConcatDataset([dataset1_train, dataset2_train])
    full_val = ConcatDataset([dataset1_val, dataset2_val])
    print("Combined dataset loaded (original + external).")
except Exception as e:
    print(f"Could not load external dataset: {e}")
    full_train = dataset1_train
    full_val = dataset1_val

class_names = dataset1_train.classes
print("Classes:", class_names)
print("Total samples:", len(full_train))
# Out:
# Loading datasets...
# Combined dataset loaded (original + external).
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# Total samples: 14158

# %%
# Create Data Loaders with proper stratified train/val split
from torch.utils.data import Subset


def extract_targets(ds):
    if isinstance(ds, ConcatDataset):
        targets = []
        for sub in ds.datasets:
            targets.extend(extract_targets(sub))
        return targets
    if hasattr(ds, "targets"):
        return list(ds.targets)
    return [ds[i][1] for i in range(len(ds))]


def stratified_split(targets, val_frac=0.2, seed=42):
    rng = np.random.default_rng(seed)
    targets = np.array(targets)
    train_idx, val_idx = [], []
    for cls in np.unique(targets):
        cls_idx = np.where(targets == cls)[0]
        rng.shuffle(cls_idx)
        if len(cls_idx) == 1:
            split = 0
        else:
            split = max(1, int(np.floor(val_frac * len(cls_idx))))
        val_idx.extend(cls_idx[:split])
        train_idx.extend(cls_idx[split:])
    rng.shuffle(train_idx)
    rng.shuffle(val_idx)
    return train_idx, val_idx


targets = extract_targets(full_train)
train_idx, val_idx = stratified_split(targets, val_frac=0.2, seed=42)

# Create Subsets
train_subset = Subset(full_train, train_idx)
val_subset = Subset(full_val, val_idx)

# Create DataLoaders
loader_kwargs = get_dataloader_kwargs(device)
train_loader = DataLoader(
    train_subset,
    batch_size=32,
    shuffle=True,  # Shuffle the subset
    drop_last=True,  # Important for BatchNorm stability
    **loader_kwargs,
)
val_loader = DataLoader(
    val_subset,
    batch_size=32,
    shuffle=False,
    **loader_kwargs,
)

print(f"Training samples: {len(train_subset)}")
print(f"Validation samples: {len(val_subset)}")
print(f"Training batches: {len(train_loader)}")
print(f"Validation batches: {len(val_loader)}")
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x000001B797AC7490>
# Traceback (most recent call last):
#   File "c:\Users\valen\miniconda3\envs\data_brain\lib\site-packages\torch\utils\data\dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "c:\Users\valen\miniconda3\envs\data_brain\lib\site-packages\torch\utils\data\dataloader.py", line 1568, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "c:\Users\valen\miniconda3\envs\data_brain\lib\multiprocessing\process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "c:\Users\valen\miniconda3\envs\data_brain\lib\multiprocessing\popen_spawn_win32.py", line 108, in wait
#     res = _winapi.WaitForSingleObject(int(self._handle), msecs)
# KeyboardInterrupt:
# Training samples: 11328
# Validation samples: 2830
# Training batches: 354
# Validation batches: 89

# %%
# Model Setup: ResNet18 with Standardized Classifier Head
num_classes = len(class_names)

# Use centralized model factory for consistency across train and serving
model = create_model('resnet18', num_classes=num_classes, pretrained=True)

# Freeze early layers (layer1, layer2), fine-tune higher representation layers (layer3, layer4)
for param in model.parameters():
    param.requires_grad = False

backbone_params = []
head_params = []
for name, param in model.named_parameters():
    if ('layer3' in name or 'layer4' in name):
        param.requires_grad = True
        backbone_params.append(param)
    elif 'fc' in name:
        param.requires_grad = True
        head_params.append(param)

model = model.to(device)
model = maybe_channels_last(model, device)
model = maybe_compile(model, device)

# Differential learning rates: lower for backbone, higher for head
optimizer = optim.AdamW(
    [
        {'params': backbone_params, 'lr': 5e-5, 'weight_decay': 1e-2},
        {'params': head_params, 'lr': 5e-4, 'weight_decay': 5e-2},
    ],
    **get_adamw_kwargs(device),
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3
)

# Loss function with label smoothing for better calibration
criterion = LabelSmoothingCrossEntropy(smoothing=0.1)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(f'Trainable parameters: {trainable:,} / {total:,} ({100 * trainable / total:.1f}%)')
print('Frozen: layer1, layer2 | Trainable: layer3, layer4, fc')
# Out:
# ⚠️  triton not available - skipping torch.compile (Windows limitation)
# Trainable parameters: 10,626,308 / 11,309,380 (94.0%)
# Frozen: layer1, layer2 | Trainable: layer3, layer4, fc

# %%
# Training Loop with Mixup & Gradient Clipping
epochs = 30
patience = 6
best_val = float("inf")
bad = 0
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

output_dir = "../runs"
model_dir = "../models"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)

metrics_file = os.path.join(output_dir, "metrics_resnet18_v2.json")
model_save_path = os.path.join(model_dir, "brain_tumor_resnet18_v2_trained.pt")

print("Starting Anti-Clever-Hans training...")
print(f"Mixup alpha={MIXUP_ALPHA}, Gradient clip={GRADIENT_CLIP}")

for epoch in range(epochs):
    # --- Training with Mixup ---
    model.train()
    tl, tc, tt = 0.0, 0, 0

    for batch_idx, (x, y) in enumerate(train_loader):
        loss_val, correct, total = train_step_with_mixup(
            model, x, y, criterion, optimizer, scaler, device, use_cuda,
            mixup_alpha=MIXUP_ALPHA, gradient_clip=GRADIENT_CLIP
        )
        tl += loss_val
        tc += correct
        tt += total

    train_loss = tl / tt
    train_acc = 100 * tc / tt

    # --- Validation (no mixup) ---
    model.eval()
    vl, vc, vt = 0.0, 0, 0
    with torch.no_grad():
        for x, y in val_loader:
            x, y = move_batch(x, y, device, use_cuda)
            with autocast_context(device):
                out = model(x)
                loss = criterion(out, y)
            vl += loss.item() * x.size(0)
            vc += (out.argmax(1) == y).sum().item()
            vt += y.size(0)

    val_loss = vl / vt
    val_acc = 100 * vc / vt

    # Scheduler step
    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]["lr"]

    # Save history
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    print(
        f"Epoch {epoch + 1:02d} | Train {train_loss:.4f}, Acc {train_acc:.2f}% | "
        f"Val {val_loss:.4f}, Acc {val_acc:.2f}% | LR {current_lr:.2e}"
    )

    # Early stopping with minimum improvement threshold
    min_delta = 0.005
    loss_gap = train_loss - val_loss

    if val_loss < (best_val - min_delta):
        best_val = val_loss
        best_state = deepcopy(model.state_dict())
        torch.save(best_state, model_save_path)
        print(f"  -> Model saved (val_loss improved to {val_loss:.4f})")
        bad = 0
    else:
        bad += 1

    # Overfitting warning
    if loss_gap > 0.25:
        print(f"  [WARNING]  Potential overfitting: gap = {loss_gap:.4f}")

    if bad >= patience:
        print(f"Early stopping after {epoch + 1} epochs")
        break
# Out:
# Starting Anti-Clever-Hans training...
# Mixup alpha=0.2, Gradient clip=1.0
# Epoch 01 | Train 0.9440, Acc 75.25% | Val 0.5986, Acc 92.12% | LR 5.00e-05
#   -> Model saved (val_loss improved to 0.5986)
#   [WARNING]  Potential overfitting: gap = 0.3455
# Epoch 02 | Train 0.8010, Acc 85.87% | Val 0.5387, Acc 95.09% | LR 5.00e-05
#   -> Model saved (val_loss improved to 0.5387)
#   [WARNING]  Potential overfitting: gap = 0.2623
# Epoch 03 | Train 0.7566, Acc 88.96% | Val 0.5160, Acc 96.11% | LR 5.00e-05
#   -> Model saved (val_loss improved to 0.5160)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 40
#      38 vl, vc, vt = 0.0, 0, 0
#      39 with torch.no_grad():
# ---> 40     for x, y in val_loader:
#      41         x, y = move_batch(x, y, device, use_cuda)
#      42         with autocast_context(device):
#
# ...

# %%
# Plot Results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Val Loss")
plt.legend()
plt.title("Loss")

plt.subplot(1, 2, 2)
plt.plot(history["train_acc"], label="Train Acc")
plt.plot(history["val_acc"], label="Val Acc")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
# Save metrics to runs directory
with open(metrics_file, 'w') as f:
    json.dump(history, f, indent=2)
print(f'Metrics saved to {metrics_file}')
print(f'Best validation loss: {best_val:.4f}')
